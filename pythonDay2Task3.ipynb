# %%
print("python\n"*100)
# Out:
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
